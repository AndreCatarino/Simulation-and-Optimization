# %% [markdown]
# ### Multi-objective optimization with differential_evolution

# %% [markdown]
# - Differential evolution is an evolutionary algorithm for solving global multivariate optimization problems by iteratively improving a candidate solution based on an evolutionary process.
# - The differential evolution method is stochastic in nature. It does not use gradient methods to find the minimum, and can search large areas of candidate space, but often requires larger numbers of function evaluations than conventional gradient-based techniques.

# %% [markdown]
# ### Optimizing Boiler efficiency with evolutionary algorithm

# %%
from scipy.optimize import differential_evolution, NonlinearConstraint, SR1
import numpy as np
import numpy as np
import matplotlib.pyplot as plt
import aux_data.example_data as example_data



outside_temp = example_data.ExampleDailyOutsideTemperature.value
energy_price = example_data.ExampleDailyEnergyCost.value

initial_boiler_temperature = 60
initial_boiler_pressure = 4
boiler_capacity = 20  # variavel
initial_water_in_boiler = 16
ideal_temperature = example_data.TEMPERATURA_IDEAL

incoming_boiler_water_temperature = (
    example_data.ExampleDailyOutsideTemperature.temperatura_entrada_agua
)

outside_temp = example_data.ExampleDailyOutsideTemperature.value
energy_price = example_data.ExampleDailyEnergyCost.value
# bounds for decision variables (boiler temperatures)
minimum_boiler_temperature = 40
maximum_boiler_temperature = 80

# Define your cost and comfort objective functions
def cost_objective(x):
    return sum(energy_price[i] * x[i] for i in range(24))

def get_confort(ideal_temperature, shower_temperature):
    # Gaussian function
    # Gain max confort when shower_temperature == ideal_temperature
    # Gain no confort when shower_temperature == ideal_temperature +- 5
    gaussian = np.exp(-((shower_temperature - ideal_temperature) ** 2) / (2 * 5**2))
    return gaussian**20


def get_shower_temperature(boiler_temperature, coeff=0.87):
    """
    coeff: lost of energy from the boiler to the shower
     - pipe insulation
     - pipe length
    """
    # Shower temperature is a function of the boiler temperature
    return coeff * boiler_temperature


def comfort_objective(x):
    return -sum(get_confort(get_shower_temperature(x[i]), ideal_temperature) for i in range(24))

# Define the combined objective function with weights
def combined_objective(x, cost_weight, comfort_weight):
    return cost_weight * cost_objective(x) + comfort_weight * comfort_objective(x)


#x0_range = (minimum_boiler_temperature, maximum_boiler_temperature)
#bounds = [(x0_range,) * 24]

bounds = [(0, maximum_boiler_temperature)] * 24

# Set weights for cost and comfort (you can adjust these)
cost_weight = 0.5
comfort_weight = 0.5

# Define a function to minimize for differential evolution
def objective_function(x):
    return combined_objective(x, cost_weight, comfort_weight)



# Define constraints
# Daiy confort has to be 16
confort_constraint = NonlinearConstraint(
    lambda x: sum(get_confort(get_shower_temperature(x[i]), ideal_temperature) for i in range(24)),
    lb=10,
    ub=24,
    jac="3-point",
    hess=SR1(),
)  


#Optimize
result = differential_evolution(
    objective_function,
    bounds,
    constraints=(confort_constraint),
    maxiter=1000,
    disp=True,
)

# Print the optimal boiler temperatures
optimized_solution = result.x
print("Optimized boiler temperatures:")
print(optimized_solution)



# You can access the cost and comfort values of the optimized solution using the respective objective functions
optimized_cost = cost_objective(optimized_solution)
optimized_comfort = -comfort_objective(optimized_solution)

print("Optimized Cost:", optimized_cost)
print("Optimized Comfort:", optimized_comfort)
# Out:
# differential_evolution step 1: f(x)= inf
# differential_evolution step 2: f(x)= inf
# differential_evolution step 3: f(x)= inf
# differential_evolution step 4: f(x)= inf
# differential_evolution step 5: f(x)= inf
# differential_evolution step 6: f(x)= inf
# differential_evolution step 7: f(x)= inf
# differential_evolution step 8: f(x)= inf
# differential_evolution step 9: f(x)= inf
# differential_evolution step 10: f(x)= inf
# differential_evolution step 11: f(x)= inf
# differential_evolution step 12: f(x)= inf
# differential_evolution step 13: f(x)= inf
# differential_evolution step 14: f(x)= inf
# differential_evolution step 15: f(x)= inf
# differential_evolution step 16: f(x)= inf
# differential_evolution step 17: f(x)= inf
# differential_evolution step 18: f(x)= inf
# differential_evolution step 19: f(x)= inf
# differential_evolution step 20: f(x)= inf
# differential_evolution step 21: f(x)= inf
# differential_evolution step 22: f(x)= inf
# differential_evolution step 23: f(x)= inf
# differential_evolution step 24: f(x)= inf
# differential_evolution step 25: f(x)= inf
# differential_evolution step 26: f(x)= inf
# differential_evolution step 27: f(x)= inf
# differential_evolution step 28: f(x)= inf
# differential_evolution step 29: f(x)= inf
# differential_evolution step 30: f(x)= inf
# differential_evolution step 31: f(x)= inf
# differential_evolution step 32: f(x)= inf
# differential_evolution step 33: f(x)= inf
# differential_evolution step 34: f(x)= inf
# differential_evolution step 35: f(x)= inf
# differential_evolution step 36: f(x)= inf
# differential_evolution step 37: f(x)= inf
# differential_evolution step 38: f(x)= inf
# differential_evolution step 39: f(x)= inf
# differential_evolution step 40: f(x)= inf
# differential_evolution step 41: f(x)= inf
# differential_evolution step 42: f(x)= inf
# differential_evolution step 43: f(x)= inf
# differential_evolution step 44: f(x)= inf
# differential_evolution step 45: f(x)= inf
# differential_evolution step 46: f(x)= inf
# differential_evolution step 47: f(x)= inf
# differential_evolution step 48: f(x)= inf
# differential_evolution step 49: f(x)= inf
# differential_evolution step 50: f(x)= inf
# differential_evolution step 51: f(x)= inf
# differential_evolution step 52: f(x)= inf
# differential_evolution step 53: f(x)= inf
# differential_evolution step 54: f(x)= inf
# differential_evolution step 55: f(x)= inf
# differential_evolution step 56: f(x)= inf
# differential_evolution step 57: f(x)= inf
# differential_evolution step 58: f(x)= inf
# differential_evolution step 59: f(x)= inf
# differential_evolution step 60: f(x)= inf
# differential_evolution step 61: f(x)= inf
# differential_evolution step 62: f(x)= inf
# differential_evolution step 63: f(x)= inf
# differential_evolution step 64: f(x)= inf
# differential_evolution step 65: f(x)= inf
# differential_evolution step 66: f(x)= inf
# differential_evolution step 67: f(x)= inf
# differential_evolution step 68: f(x)= inf
# differential_evolution step 69: f(x)= inf
# differential_evolution step 70: f(x)= inf
# differential_evolution step 71: f(x)= inf
# differential_evolution step 72: f(x)= inf
# differential_evolution step 73: f(x)= inf
# differential_evolution step 74: f(x)= inf
# differential_evolution step 75: f(x)= inf
# differential_evolution step 76: f(x)= inf
# differential_evolution step 77: f(x)= inf
# differential_evolution step 78: f(x)= inf
# differential_evolution step 79: f(x)= inf
# differential_evolution step 80: f(x)= inf
# differential_evolution step 81: f(x)= inf
# differential_evolution step 82: f(x)= inf
# differential_evolution step 83: f(x)= inf
# differential_evolution step 84: f(x)= inf
# differential_evolution step 85: f(x)= inf
# differential_evolution step 86: f(x)= inf
# differential_evolution step 87: f(x)= inf
# differential_evolution step 88: f(x)= inf
# differential_evolution step 89: f(x)= inf
# differential_evolution step 90: f(x)= inf
# differential_evolution step 91: f(x)= inf
# differential_evolution step 92: f(x)= inf
# differential_evolution step 93: f(x)= inf
# differential_evolution step 94: f(x)= inf
# differential_evolution step 95: f(x)= inf
# differential_evolution step 96: f(x)= 245.797
# differential_evolution step 97: f(x)= 245.797
# differential_evolution step 98: f(x)= 245.797
# differential_evolution step 99: f(x)= 245.797
# differential_evolution step 100: f(x)= 245.797
# differential_evolution step 101: f(x)= 245.797
# differential_evolution step 102: f(x)= 245.797
# differential_evolution step 103: f(x)= 245.797
# differential_evolution step 104: f(x)= 245.797
# differential_evolution step 105: f(x)= 245.797
# differential_evolution step 106: f(x)= 245.797
# differential_evolution step 107: f(x)= 245.797
# differential_evolution step 108: f(x)= 245.797
# differential_evolution step 109: f(x)= 245.797
# differential_evolution step 110: f(x)= 245.797
# differential_evolution step 111: f(x)= 245.797
# differential_evolution step 112: f(x)= 245.797
# differential_evolution step 113: f(x)= 245.797
# differential_evolution step 114: f(x)= 245.797
# differential_evolution step 115: f(x)= 232.042
# differential_evolution step 116: f(x)= 232.042
# differential_evolution step 117: f(x)= 227.325
# differential_evolution step 118: f(x)= 210.348
# differential_evolution step 119: f(x)= 210.348
# differential_evolution step 120: f(x)= 210.348
# differential_evolution step 121: f(x)= 210.348
# differential_evolution step 122: f(x)= 210.348
# differential_evolution step 123: f(x)= 210.348
# differential_evolution step 124: f(x)= 210.348
# differential_evolution step 125: f(x)= 210.348
# differential_evolution step 126: f(x)= 210.348
# differential_evolution step 127: f(x)= 210.348
# differential_evolution step 128: f(x)= 210.348
# differential_evolution step 129: f(x)= 210.348
# differential_evolution step 130: f(x)= 210.348
# differential_evolution step 131: f(x)= 210.348
# differential_evolution step 132: f(x)= 210.348
# differential_evolution step 133: f(x)= 210.348
# differential_evolution step 134: f(x)= 210.348
# differential_evolution step 135: f(x)= 210.348
# differential_evolution step 136: f(x)= 210.348
# differential_evolution step 137: f(x)= 210.348
# differential_evolution step 138: f(x)= 210.348
# differential_evolution step 139: f(x)= 210.348
# differential_evolution step 140: f(x)= 210.348
# differential_evolution step 141: f(x)= 210.348
# differential_evolution step 142: f(x)= 210.348
# differential_evolution step 143: f(x)= 206.435
# differential_evolution step 144: f(x)= 206.435
# differential_evolution step 145: f(x)= 205.786
# differential_evolution step 146: f(x)= 205.786
# differential_evolution step 147: f(x)= 205.786
# differential_evolution step 148: f(x)= 205.786
# differential_evolution step 149: f(x)= 201.389
# differential_evolution step 150: f(x)= 201.389
# differential_evolution step 151: f(x)= 200.806
# differential_evolution step 152: f(x)= 200.806
# differential_evolution step 153: f(x)= 200.806
# differential_evolution step 154: f(x)= 199.894
# differential_evolution step 155: f(x)= 199.894
# differential_evolution step 156: f(x)= 199.894
# differential_evolution step 157: f(x)= 181.257
# differential_evolution step 158: f(x)= 181.257
# differential_evolution step 159: f(x)= 181.257
# differential_evolution step 160: f(x)= 181.257
# differential_evolution step 161: f(x)= 181.257
# differential_evolution step 162: f(x)= 181.257
# differential_evolution step 163: f(x)= 181.257
# differential_evolution step 164: f(x)= 181.257
# differential_evolution step 165: f(x)= 181.257
# differential_evolution step 166: f(x)= 181.257
# differential_evolution step 167: f(x)= 181.257
# differential_evolution step 168: f(x)= 181.257
# differential_evolution step 169: f(x)= 181.257
# differential_evolution step 170: f(x)= 180.969
# differential_evolution step 171: f(x)= 180.969
# differential_evolution step 172: f(x)= 180.969
# differential_evolution step 173: f(x)= 180.969
# differential_evolution step 174: f(x)= 180.969
# differential_evolution step 175: f(x)= 180.969
# differential_evolution step 176: f(x)= 180.969
# differential_evolution step 177: f(x)= 180.969
# differential_evolution step 178: f(x)= 177.83
# differential_evolution step 179: f(x)= 177.83
# differential_evolution step 180: f(x)= 177.83
# differential_evolution step 181: f(x)= 169.83
# differential_evolution step 182: f(x)= 169.83
# differential_evolution step 183: f(x)= 169.83
# differential_evolution step 184: f(x)= 169.83
# differential_evolution step 185: f(x)= 169.83
# differential_evolution step 186: f(x)= 169.83
# differential_evolution step 187: f(x)= 169.83
# differential_evolution step 188: f(x)= 169.83
# differential_evolution step 189: f(x)= 169.83
# differential_evolution step 190: f(x)= 169.83
# differential_evolution step 191: f(x)= 169.83
# differential_evolution step 192: f(x)= 169.83
# differential_evolution step 193: f(x)= 169.83
# differential_evolution step 194: f(x)= 169.83
# differential_evolution step 195: f(x)= 169.83
# differential_evolution step 196: f(x)= 169.83
# differential_evolution step 197: f(x)= 169.83
# differential_evolution step 198: f(x)= 169.83
# differential_evolution step 199: f(x)= 169.83
# differential_evolution step 200: f(x)= 169.83
# differential_evolution step 201: f(x)= 169.83
# differential_evolution step 202: f(x)= 169.83
# differential_evolution step 203: f(x)= 164.744
# differential_evolution step 204: f(x)= 164.744
# differential_evolution step 205: f(x)= 164.744
# differential_evolution step 206: f(x)= 164.744
# differential_evolution step 207: f(x)= 164.744
# differential_evolution step 208: f(x)= 164.744
# differential_evolution step 209: f(x)= 164.744
# differential_evolution step 210: f(x)= 164.744
# differential_evolution step 211: f(x)= 164.744
# differential_evolution step 212: f(x)= 164.744
# differential_evolution step 213: f(x)= 164.744
# differential_evolution step 214: f(x)= 164.744
# differential_evolution step 215: f(x)= 164.744
# differential_evolution step 216: f(x)= 164.744
# differential_evolution step 217: f(x)= 164.744
# differential_evolution step 218: f(x)= 164.744
# differential_evolution step 219: f(x)= 164.744
# differential_evolution step 220: f(x)= 164.744
# differential_evolution step 221: f(x)= 164.744
# differential_evolution step 222: f(x)= 164.744
# differential_evolution step 223: f(x)= 161.389
# differential_evolution step 224: f(x)= 161.389
# differential_evolution step 225: f(x)= 161.389
# differential_evolution step 226: f(x)= 154.367
# differential_evolution step 227: f(x)= 154.367
# differential_evolution step 228: f(x)= 154.367
# differential_evolution step 229: f(x)= 154.367
# differential_evolution step 230: f(x)= 154.367
# differential_evolution step 231: f(x)= 154.367
# differential_evolution step 232: f(x)= 154.367
# differential_evolution step 233: f(x)= 154.367
# differential_evolution step 234: f(x)= 154.367
# differential_evolution step 235: f(x)= 154.367
# differential_evolution step 236: f(x)= 154.367
# differential_evolution step 237: f(x)= 154.367
# differential_evolution step 238: f(x)= 154.367
# differential_evolution step 239: f(x)= 154.367
# differential_evolution step 240: f(x)= 154.367
# differential_evolution step 241: f(x)= 154.367
# differential_evolution step 242: f(x)= 154.367
# differential_evolution step 243: f(x)= 154.367
# differential_evolution step 244: f(x)= 154.367
# differential_evolution step 245: f(x)= 154.367
# differential_evolution step 246: f(x)= 154.367
# differential_evolution step 247: f(x)= 154.367
# differential_evolution step 248: f(x)= 154.367
# differential_evolution step 249: f(x)= 154.367
# differential_evolution step 250: f(x)= 154.367
# differential_evolution step 251: f(x)= 151.473
# differential_evolution step 252: f(x)= 151.473
# differential_evolution step 253: f(x)= 151.473
# differential_evolution step 254: f(x)= 151.473
# differential_evolution step 255: f(x)= 150.465
# differential_evolution step 256: f(x)= 149.388
# differential_evolution step 257: f(x)= 149.388
# differential_evolution step 258: f(x)= 149.388
# differential_evolution step 259: f(x)= 149.388
# differential_evolution step 260: f(x)= 149.388
# differential_evolution step 261: f(x)= 149.388
# differential_evolution step 262: f(x)= 149.388
# differential_evolution step 263: f(x)= 146.84
# differential_evolution step 264: f(x)= 146.84
# differential_evolution step 265: f(x)= 146.84
# differential_evolution step 266: f(x)= 146.84
# differential_evolution step 267: f(x)= 146.84
# differential_evolution step 268: f(x)= 135.971
# differential_evolution step 269: f(x)= 135.971
# differential_evolution step 270: f(x)= 135.971
# differential_evolution step 271: f(x)= 135.971
# differential_evolution step 272: f(x)= 135.971
# differential_evolution step 273: f(x)= 135.971
# differential_evolution step 274: f(x)= 135.971
# differential_evolution step 275: f(x)= 135.051
# differential_evolution step 276: f(x)= 135.051
# differential_evolution step 277: f(x)= 135.051
# differential_evolution step 278: f(x)= 135.051
# differential_evolution step 279: f(x)= 135.051
# differential_evolution step 280: f(x)= 135.051
# differential_evolution step 281: f(x)= 135.051
# differential_evolution step 282: f(x)= 135.051
# differential_evolution step 283: f(x)= 132.849
# differential_evolution step 284: f(x)= 132.849
# differential_evolution step 285: f(x)= 132.849
# differential_evolution step 286: f(x)= 132.849
# differential_evolution step 287: f(x)= 132.849
# differential_evolution step 288: f(x)= 132.849
# differential_evolution step 289: f(x)= 132.849
# differential_evolution step 290: f(x)= 132.849
# differential_evolution step 291: f(x)= 132.849
# differential_evolution step 292: f(x)= 132.849
# differential_evolution step 293: f(x)= 130.676
# differential_evolution step 294: f(x)= 130.676
# differential_evolution step 295: f(x)= 130.676
# differential_evolution step 296: f(x)= 128.689
# differential_evolution step 297: f(x)= 127.986
# differential_evolution step 298: f(x)= 127.986
# differential_evolution step 299: f(x)= 127.986
# differential_evolution step 300: f(x)= 127.625
# differential_evolution step 301: f(x)= 127.625
# differential_evolution step 302: f(x)= 127.625
# differential_evolution step 303: f(x)= 127.625
# differential_evolution step 304: f(x)= 127.625
# differential_evolution step 305: f(x)= 127.625
# differential_evolution step 306: f(x)= 127.625
# differential_evolution step 307: f(x)= 127.625
# differential_evolution step 308: f(x)= 127.625
# differential_evolution step 309: f(x)= 127.625
# differential_evolution step 310: f(x)= 127.625
# differential_evolution step 311: f(x)= 125.162
# differential_evolution step 312: f(x)= 125.162
# differential_evolution step 313: f(x)= 125.162
# differential_evolution step 314: f(x)= 125.162
# differential_evolution step 315: f(x)= 125.162
# differential_evolution step 316: f(x)= 125.162
# differential_evolution step 317: f(x)= 124.155
# differential_evolution step 318: f(x)= 124.155
# differential_evolution step 319: f(x)= 124.155
# differential_evolution step 320: f(x)= 124.155
# differential_evolution step 321: f(x)= 124.15
# differential_evolution step 322: f(x)= 124.15
# differential_evolution step 323: f(x)= 124.15
# differential_evolution step 324: f(x)= 124.15
# differential_evolution step 325: f(x)= 124.15
# differential_evolution step 326: f(x)= 124.15
# differential_evolution step 327: f(x)= 124.15
# differential_evolution step 328: f(x)= 124.15
# differential_evolution step 329: f(x)= 124.15
# differential_evolution step 330: f(x)= 124.15
# differential_evolution step 331: f(x)= 121.863
# differential_evolution step 332: f(x)= 119.188
# differential_evolution step 333: f(x)= 119.188
# differential_evolution step 334: f(x)= 119.188
# differential_evolution step 335: f(x)= 119.188
# differential_evolution step 336: f(x)= 119.188
# differential_evolution step 337: f(x)= 119.188
# differential_evolution step 338: f(x)= 119.188
# differential_evolution step 339: f(x)= 119.188
# differential_evolution step 340: f(x)= 119.188
# differential_evolution step 341: f(x)= 119.188
# differential_evolution step 342: f(x)= 119.188
# differential_evolution step 343: f(x)= 119.188
# differential_evolution step 344: f(x)= 119.188
# differential_evolution step 345: f(x)= 119.188
# differential_evolution step 346: f(x)= 119.188
# differential_evolution step 347: f(x)= 119.188
# differential_evolution step 348: f(x)= 119.188
# differential_evolution step 349: f(x)= 119.188
# differential_evolution step 350: f(x)= 119.188
# differential_evolution step 351: f(x)= 119.188
# differential_evolution step 352: f(x)= 119.188
# differential_evolution step 353: f(x)= 119.188
# differential_evolution step 354: f(x)= 119.188
# differential_evolution step 355: f(x)= 119.188
# differential_evolution step 356: f(x)= 119.188
# differential_evolution step 357: f(x)= 119.188
# differential_evolution step 358: f(x)= 119.188
# differential_evolution step 359: f(x)= 119.188
# differential_evolution step 360: f(x)= 119.188
# differential_evolution step 361: f(x)= 119.188
# differential_evolution step 362: f(x)= 118.469
# differential_evolution step 363: f(x)= 118.469
# differential_evolution step 364: f(x)= 118.469
# differential_evolution step 365: f(x)= 118.469
# differential_evolution step 366: f(x)= 118.469
# differential_evolution step 367: f(x)= 118.469
# differential_evolution step 368: f(x)= 118.469
# differential_evolution step 369: f(x)= 118.469
# differential_evolution step 370: f(x)= 118.469
# differential_evolution step 371: f(x)= 118.469
# differential_evolution step 372: f(x)= 118.469
# differential_evolution step 373: f(x)= 118.469
# differential_evolution step 374: f(x)= 118.469
# differential_evolution step 375: f(x)= 118.469
# differential_evolution step 376: f(x)= 118.469
# differential_evolution step 377: f(x)= 118.308
# differential_evolution step 378: f(x)= 118.308
# differential_evolution step 379: f(x)= 118.308
# differential_evolution step 380: f(x)= 118.308
# differential_evolution step 381: f(x)= 118.308
# differential_evolution step 382: f(x)= 118.308
# differential_evolution step 383: f(x)= 118.308
# differential_evolution step 384: f(x)= 118.308
# differential_evolution step 385: f(x)= 118.308
# differential_evolution step 386: f(x)= 117.505
# differential_evolution step 387: f(x)= 117.505
# differential_evolution step 388: f(x)= 117.505
# differential_evolution step 389: f(x)= 117.505
# differential_evolution step 390: f(x)= 117.505
# differential_evolution step 391: f(x)= 117.505
# differential_evolution step 392: f(x)= 117.505
# differential_evolution step 393: f(x)= 117.505
# differential_evolution step 394: f(x)= 117.505
# differential_evolution step 395: f(x)= 116.4
# differential_evolution step 396: f(x)= 116.4
# differential_evolution step 397: f(x)= 116.4
# differential_evolution step 398: f(x)= 116.4
# differential_evolution step 399: f(x)= 116.4
# differential_evolution step 400: f(x)= 116.4
# differential_evolution step 401: f(x)= 116.4
# differential_evolution step 402: f(x)= 116.4
# differential_evolution step 403: f(x)= 116.4
# differential_evolution step 404: f(x)= 116.4
# differential_evolution step 405: f(x)= 116.4
# differential_evolution step 406: f(x)= 116.102
# differential_evolution step 407: f(x)= 116.102
# differential_evolution step 408: f(x)= 116.102
# differential_evolution step 409: f(x)= 116.102
# differential_evolution step 410: f(x)= 116.102
# differential_evolution step 411: f(x)= 116.102
# differential_evolution step 412: f(x)= 116.102
# differential_evolution step 413: f(x)= 116.102
# differential_evolution step 414: f(x)= 116.102
# differential_evolution step 415: f(x)= 116.102
# differential_evolution step 416: f(x)= 116.03
# differential_evolution step 417: f(x)= 115.384
# differential_evolution step 418: f(x)= 115.384
# differential_evolution step 419: f(x)= 115.384
# differential_evolution step 420: f(x)= 115.384
# differential_evolution step 421: f(x)= 115.384
# differential_evolution step 422: f(x)= 115.384
# differential_evolution step 423: f(x)= 115.384
# differential_evolution step 424: f(x)= 115.384
# differential_evolution step 425: f(x)= 115.384
# differential_evolution step 426: f(x)= 115.303
# differential_evolution step 427: f(x)= 115.296
# differential_evolution step 428: f(x)= 115.296
# differential_evolution step 429: f(x)= 115.296
# differential_evolution step 430: f(x)= 115.296
# differential_evolution step 431: f(x)= 115.296
# differential_evolution step 432: f(x)= 115.296
# differential_evolution step 433: f(x)= 115.296
# differential_evolution step 434: f(x)= 114.685
# differential_evolution step 435: f(x)= 114.685
# differential_evolution step 436: f(x)= 114.685
# differential_evolution step 437: f(x)= 114.685
# differential_evolution step 438: f(x)= 114.685
# differential_evolution step 439: f(x)= 114.685
# differential_evolution step 440: f(x)= 114.685
# differential_evolution step 441: f(x)= 114.685
# differential_evolution step 442: f(x)= 114.685
# differential_evolution step 443: f(x)= 114.685
# differential_evolution step 444: f(x)= 114.586
# differential_evolution step 445: f(x)= 114.586
# differential_evolution step 446: f(x)= 114.586
# differential_evolution step 447: f(x)= 114.586
# differential_evolution step 448: f(x)= 114.586
# differential_evolution step 449: f(x)= 114.586
# differential_evolution step 450: f(x)= 114.586
# differential_evolution step 451: f(x)= 114.586
# differential_evolution step 452: f(x)= 114.586
# differential_evolution step 453: f(x)= 114.586
# differential_evolution step 454: f(x)= 114.133
# differential_evolution step 455: f(x)= 114.133
# differential_evolution step 456: f(x)= 114.133
# differential_evolution step 457: f(x)= 114.133
# differential_evolution step 458: f(x)= 114.133
# differential_evolution step 459: f(x)= 114.133
# differential_evolution step 460: f(x)= 114.133
# differential_evolution step 461: f(x)= 114.133
# differential_evolution step 462: f(x)= 114.133
# differential_evolution step 463: f(x)= 114.133
# differential_evolution step 464: f(x)= 114.133
# differential_evolution step 465: f(x)= 114.133
# differential_evolution step 466: f(x)= 114.133
# differential_evolution step 467: f(x)= 114.133
# differential_evolution step 468: f(x)= 114.133
# differential_evolution step 469: f(x)= 114.133
# differential_evolution step 470: f(x)= 114.133
# differential_evolution step 471: f(x)= 114.133
# differential_evolution step 472: f(x)= 114.133
# Polishing solution with 'trust-constr'
# Optimized boiler temperatures:
# [4.48307057e+01 4.29276870e-08 4.54290175e+01 6.69657844e-08
#  4.53918085e+01 3.90446950e-08 5.77845662e-08 4.52148732e+01
#  4.52072018e+01 4.52070708e+01 4.52071582e+01 4.52072019e+01
#  5.10792554e-08 5.07481646e-08 3.67462109e-08 4.51939347e+01
#  4.52028175e+01 5.08004599e-08 5.00923974e-08 4.51662916e+01
#  4.71868084e-08 3.87618759e-08 4.52384468e+01 4.39488701e-08]
# Optimized Cost: 234.82565872915558
# Optimized Comfort: 10.000000131023551
# d:\Anaconda\envs\optimization_forecasting_env\lib\site-packages\scipy\optimize\_hessian_update_strategy.py:182: UserWarning: delta_grad == 0.0. Check if the approximated function is linear. If the function is linear better results can be obtained by defining the Hessian as zero instead of using quasi-Newton approximations.
#   warn('delta_grad == 0.0. Check if the approximated '
